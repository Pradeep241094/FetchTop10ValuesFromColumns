# %% [markdown]
# <a href="https://colab.research.google.com/github/Pradeep241094/FetchTop10ValuesFromColumns/blob/master/FetchTop10Values.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

fileData = pd.read_csv("/content/testFile.csv", sep=',',encoding='utf-8')


print(fileData.head())
# Out:
#    Column1.1  Column1.2  Column1.3  ...  Column1.199  Column1.200  Column1.201
# 0          0          0          0  ...            0            0          NaN
# 1          0         14        116  ...            0            0          NaN
# 2        121          0        659  ...          710          333          NaN
# 3        112         68        306  ...          243          214          NaN
# 4          0          0          0  ...            0            0          NaN
#
# [5 rows x 201 columns]

# %%
fileData.to_csv("newTest.csv")

# %%
df=pd.read_csv('newTest.csv',sep=',',encoding='utf-8')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Column1.1', 'Column1.2', 'Column1.3', 'Column1.4',
#        'Column1.5', 'Column1.6', 'Column1.7', 'Column1.8', 'Column1.9',
#        ...
#        'Column1.192', 'Column1.193', 'Column1.194', 'Column1.195',
#        'Column1.196', 'Column1.197', 'Column1.198', 'Column1.199',
#        'Column1.200', 'Column1.201'],
#       dtype='object', length=202)

# %%
df.drop(['Unnamed: 0'],axis=1)
# Out:
#        Column1.1  Column1.2  Column1.3  ...  Column1.199  Column1.200  Column1.201
# 0              0          0          0  ...            0            0          NaN
# 1              0         14        116  ...            0            0          NaN
# 2            121          0        659  ...          710          333          NaN
# 3            112         68        306  ...          243          214          NaN
# 4              0          0          0  ...            0            0          NaN
# ...          ...        ...        ...  ...          ...          ...          ...
# 11584          0         16          0  ...            0            0          NaN
# 11585          0          0          0  ...            0            0          NaN
# 11586          0          0          3  ...            0            0          NaN
# 11587          0          0          0  ...            0            0          NaN
# ...

# %%
df['Column1.1'].nlargest(10)
# Out:
# 7       4772
# 77      1526
# 9        951
# 27       849
# 186      777
# 198      725
# 5236     695
# 20       616
# 336      554
# 45       551
# Name: Column1.1, dtype: int64

# %% [markdown]
# This Identifies the index and filters out the top 10 values for one column in the csv file

# %%
for label, content in df.items():
  result = df[label].nlargest(10)
  print(result)
# Out:
# 11588    11588
# 11587    11587
# 11586    11586
# 11585    11585
# 11584    11584
# 11583    11583
# 11582    11582
# 11581    11581
# 11580    11580
# 11579    11579
# Name: Unnamed: 0, dtype: int64
# 7       4772
# 77      1526
# 9        951
# 27       849
# 186      777
# 198      725
# 5236     695
# 20       616
# 336      554
# 45       551
# Name: Column1.1, dtype: int64
# 7        2170
# 27       1350
# 409      1306
# 11509    1253
# 186      1224
# 646      1180
# 30       1150
# 12       1013
# 77       1009
# 11520     839
# Name: Column1.2, dtype: int64
# 7      7579
# 30     4538
# 54     3902
# 27     3732
# 9      3725
# 102    3648
# 20     3114
# 77     3102
# 45     2734
# 628    2517
# Name: Column1.3, dtype: int64
# 7      1224
# 54      857
# 41      807
# 646     799
# 77      747
# 27      673
# 20      661
# 45      587
# 186     561
# 628     543
# Name: Column1.4, dtype: int64
# 7     4454
# 20    3449
# 27    2195
# 9     1995
# 77    1961
# 30    1671
# ...

# %% [markdown]
# This Identifies top 10 values for all columns (Topics) in the CSV file. The values of the indexes starts with 0, Hence for words increment it by 1.
